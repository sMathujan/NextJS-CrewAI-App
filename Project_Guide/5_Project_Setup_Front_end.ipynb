# %% [markdown]
# ## Setup Project Front End
#
# 1. Create the next app.
# `npx create-next-app@latest nextjs_app --typescript --tailwind --eslint`
#
# ![image.png](attachment:image.png)
#
#
# 2. Command to run the nextjs application.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## What we are going to build
#
# 1. Header
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# 2. Input Section
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
#
# 3. Event Session
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
#
# 4. Final Output
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
#
# 5. Hooks - useCrewJob.tsx
#
# ![image-9.png](attachment:image-9.png)
#
# We're going to store all the information for the companies and positions, we add and it's going to store the final output and the event details. So it's basically going to do all the heavy lifting for us of pinging our backend and saving the state for everything on our front end.

# %% [markdown]
# ## Setup Header
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Setup Page Layout
#
# ![image.png](attachment:image.png)
