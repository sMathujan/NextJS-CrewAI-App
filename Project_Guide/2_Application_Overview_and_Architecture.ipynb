# %% [markdown]
# 1. Application Overview
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Application Architecture
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.1. We can put in our inputs of the companies and positions, we want to research on the front end then we can click run.
#
# 2.2. It'll make a request to our flask backend so that's our python backend that's going to be running all of our crew AI stuff.
#
# 2.3. It takes 5 minutes for the crew to go off and run do all the research and then finally return that to the front end.
#
# 2.4 We're going to first give it an ID so let's just say ID one and then what we're going to do is just go kick off that crew and just say hey go run in the background.
#
# 2.5. Then what this crew is going to do is like I said it's going to run in the background and then we're instantly going to return a job ID to our front end.
#
# 2.6. Here's why we're going to do that what we've set up is a basically an in-memory database that is going to connect you know job one is connected to the background crew number one and what this background crew is going to do is as it makes progress and has updates for different research it's going to do it's going to pass along the research to our little in-memory database.
#
# 2.7. Then, Now what we can do is start pinging the back end with our API get crew ID and we can start getting the status of that job.
#
# 2.8 what we'll do is say like okay it's been 1 second so we'll just ping the back in do you have any updates for me oh it actually looks like you found the CEO of the company.
#
# 2.9. It'll quickly update our events table down here and we're just going to
# continually pull it over and over and over again until we get the final result and the status of the job is complete.

# %% [markdown]
# **First, we are going to code the backend and then we code frontend.**
