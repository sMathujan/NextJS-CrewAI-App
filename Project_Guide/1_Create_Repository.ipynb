# %% [markdown]
# 1. Create the Github repository for the project.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Clone the Github repo to the working environment.
#
# 3. `Project_Guide` folder contains the detailed implementation of the project.
