# %% [markdown]
# 1. Create the backend foleder.
# `mkdir crewai_be`

# %% [markdown]
# 2. Create project files.
#
# `api.py` -> Run Flask Backend server.
# Whenever, we are going to make an api call to backend application, we are going to use this file.
#
# `crew.py` -> Create crews by connecting Agents and Tasks.
#
# `tasks.py` -> Defining specific task that need to be execute.
#
# `agents.py` -> Store the logic for running all the agents, describing the agents (goal, backstory, etc)
#
# `models.py` -> Setup Pydantic models.
# Whenever, we need to start working on the frontend code, we need our data to be formatted in a very specific manner.
#
# `job_manager.py` -> Handle Log CrewAI job status.
#
# `tools\youtube_search_tools.py` -> Search YouTube videos that relate to the companies and job positions.
#
# `pyproject.toml` -> Handle dependencies, project settings and metadata.
# Copy and paste the code for pyproject.toml file.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Install backend dependencies.
#
# `cd crewai_be`
#
# Run command `poetry install --no-root`. This will install the all the dependicies and put all them into the python environment.
#
# `pip install poetry` to install the poetry to your backend environment.
#
# 4. Activate the conda environment.
# `poetry shell`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Setupi api.py
#
# 1. Write the code for `api.py` file. Whenever, we send the requests to the backend, this file is going to handle this.
#
# 2. Run the file by `python api.py` and check with the postman.
#
# ![image.png](attachment:image.png)
#
#
# 3. Validate the POST request.
#
# ![image-2.png](attachment:image-2.png)
#
#
# 4. Write the POST request to kickoff the crew and kickoff thread.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Setup crew.py
#
# 1. When it comes to setting up this crew it's actually going to be a lot different than the way we go about normally creating Crews. Normally, we do that in the main.py file to where we usually just run it with a command line. But in this case what we're going to create a crew per request that the user sends us. So this is going to allow us, if a user requests to look up Tesla and the CEO that's going to kick off its own crew and then if someone else wants to see Ford and the CTO we can go kick off another crew for them. This is going to allow us to run them in parallel.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Setup job_manager.py
#
# 1. Inside job manager, we write the code for the logic for appending events and logging what's going on inside of our crew.
#
# 2. We want to only allow one of these Crews to make information changes to this dictionary or database at a time. Because we're starting to to work with multi-threaded processes. If we're working on this database updating the database on this thread and then this thread's also trying to make changes to it. We're actually just going to run into some errors so all we need to do is basically allow only one of you guys can make changes to this database at a time. So, we're going to lock our data and we're going to protect it to only allow this appended event to make one change at a time. so here's how we're going to do that we are going to create a jobs lock. It's really just an in-memory database.
#
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Add Append Events
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Setup Agents
#
# 1. Write the code inside agents.py.
#
# ![image.png](attachment:image.png)
#
#
# 2. Define the agents inside the crew.py.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Setup Tasks & Models
#
# 1. Write the code for tasks.py.
#
# ![image.png](attachment:image.png)
#
#
# 2. Write the code inside models.py.
#
# ![image-2.png](attachment:image-2.png)
#
#
# 3. Define tasks inside crew.py.
#
# ![image-3.png](attachment:image-3.png)
#
#
# 4. Create the crew inside the crew.py.
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Kickoff Crew
#
# 1. Setup the crew inside api.py.
#
# ![image.png](attachment:image.png)
#
#
# 2. Fetch crew inside api.py.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Setup Tools
#
# 1. Write the code inside `tools/youtube_search_tools.py`.
#
# ![image.png](attachment:image.png)
#
#
# 2. Define the tools for the agents.
#
# ![image-2.png](attachment:image-2.png)
#
#
# 3. Create `.env` file, to store all environment variables specific for API keys (OpenAI API key, YouTube API key).
